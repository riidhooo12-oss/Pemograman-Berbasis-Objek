# %% [markdown]
# <a href="https://colab.research.google.com/github/riidhooo12-oss/Pemograman-Berbasis-Objek/blob/main/Jobsheet_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 Tipe Data Dasar

# %%
# Number
angka_int = 10
print("angka_int =", angka_int, "->", type(angka_int))

angka_float = 3.14
print("angka_float =", angka_float, "->", type(angka_float))

angka_complex = 2 + 3j
print("angka_complex =", angka_complex, "->", type(angka_complex))

# Boolean
is_active = True
print("is_active =", is_active, "->", type(is_active))

# String
teks = "Hello, Python!"
print("teks =", teks, "->", type(teks))

# List
daftar_angka = [1, 2, 3, 4, 5]
print("daftar_angka =", daftar_angka, "->", type(daftar_angka))

# Tuple
koordinat = (10, 20)
print("koordinat =", koordinat, "->", type(koordinat))

# Dictionary
data_mahasiswa = {
    "nama": "Andi",
    "nim": "A11.2022.12345",
    "jurusan": "Teknik Informatika"
}
print("data_mahasiswa =", data_mahasiswa, "->", type(data_mahasiswa))

# Set
himpunan_angka = {1, 2, 3, 2, 1}
print("himpunan_angka =", himpunan_angka, "->", type(himpunan_angka))

# Konversi
nilai_str = "100"
nilai_int = int(nilai_str)
print("nilai_int =", nilai_int, "->", type(nilai_int))
# Out:
# angka_int = 10 -> <class 'int'>
# angka_float = 3.14 -> <class 'float'>
# angka_complex = (2+3j) -> <class 'complex'>
# is_active = True -> <class 'bool'>
# teks = Hello, Python! -> <class 'str'>
# daftar_angka = [1, 2, 3, 4, 5] -> <class 'list'>
# koordinat = (10, 20) -> <class 'tuple'>
# data_mahasiswa = {'nama': 'Andi', 'nim': 'A11.2022.12345', 'jurusan': 'Teknik Informatika'} -> <class 'dict'>
# himpunan_angka = {1, 2, 3} -> <class 'set'>
# nilai_int = 100 -> <class 'int'>

# %% [markdown]
# Praktikum 02 Variabel dan operasi

# %%
nama = "Budi"
umur = 20
tinggi = 170.5
is_student = True

print(nama, umur, tinggi, is_student)

a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)

print(a > b)
print(a == b)

x = True
y = False

print(x and y)
print(x or y)
print(not x)

if a > b:
    print("a lebih besar dari b")
# Out:
# Budi 20 170.5 True
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000
# True
# False
# False
# True
# False
# a lebih besar dari b

# %% [markdown]
#   Praktikum 03 Percabangan

# %%
nilai = 85
if nilai > 80:
    print("Lulus")

umur = 17
if umur >= 18:
    print("Boleh SIM")
else:
    print("Belum boleh")

hari = "Rabu"
if hari == "Senin":
    print("Kerja")
elif hari == "Rabu":
    print("Diskon")
else:
    print("Hari biasa")

suhu = 35
if suhu > 30:
    if suhu > 40:
        print("Sangat panas")
    else:
        print("Panas")

angka = -5
status = "Positif" if angka > 0 else "Negatif"
print(status)
# Out:
# Lulus
# Belum boleh
# Diskon
# Panas
# Negatif

# %% [markdown]
# Praktikum 04 Perulangan

# %%
for i in range(5):
    print(i)

buah = ["apel", "mangga"]
for b in buah:
    print(b)

count = 0
while count < 5:
    print(count)
    count += 1

for i in range(10):
    if i == 3:
        break
    print(i)

for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# apel
# mangga
# 0
# 1
# 2
# 3
# 4
# 0
# 1
# 2
# 0
# 1
# 3
# 4

# %% [markdown]
# Penugasan 01

# %%
# Program BMI

# Input
berat = float(input("Masukkan berat badan (kg): "))
tinggi_cm = float(input("Masukkan tinggi badan (cm): "))

# Proses
tinggi_m = tinggi_cm / 100
bmi = berat / (tinggi_m ** 2)

# Output
print("Nilai BMI =", bmi)

if bmi < 18.5:
    kategori = "Underweight"
elif 18.5 <= bmi <= 24.9:
    kategori = "Normal"
elif 25 <= bmi <= 29.9:
    kategori = "Overweight"
else:
    kategori = "Obesitas"

print("Kategori =", kategori)
# Out:
# Masukkan berat badan (kg): 60
# Masukkan tinggi badan (cm): 173
# Nilai BMI = 20.04744562130375
# Kategori = Normal

# %% [markdown]
# Penugasan 02

# %%
# Program cek bilangan

angka = int(input("Masukkan bilangan: "))

# Cek genap/ganjil
if angka % 2 == 0:
    print("Bilangan Genap")
else:
    print("Bilangan Ganjil")

# Cek prima
if angka > 1:
    prima = True
    for i in range(2, angka):
        if angka % i == 0:
            prima = False
            break

    if prima:
        print("Bilangan Prima")
    else:
        print("Bukan Bilangan Prima")
else:
    print("Bukan Bilangan Prima")
# Out:
# Masukkan bilangan: 5
# Bilangan Ganjil
# Bilangan Prima
